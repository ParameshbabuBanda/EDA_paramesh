# %% [raw]
# # Import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import os

# %%
visa_df=pd.read_csv(r'C:\Users\param\OneDrive\Documents\EDA file\DataFile\Visadataset.csv')

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat_columns=visa_df.select_dtypes(include='object').columns
num_columns=visa_df.select_dtypes(exclude='object').columns
cat_columns,num_columns
# Out:
# (Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#         'requires_job_training', 'region_of_employment', 'unit_of_wage',
#         'full_time_position', 'case_status'],
#        dtype='object'),
#  Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object'))

# %%
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# # Prevailing_wage

# %%
visa_df.loc[:,'prevailing_wage']  # give column name  == series type
visa_df.iloc[:,[8]]               # give column index number  == data frame type
visa_df['prevailing_wage']        # give column name  == series type
visa_df[['prevailing_wage']]      # give column name  ==  dataframe type
# Out:
#        prevailing_wage
# 0             592.2029
# 1           83425.6500
# 2          122996.8600
# 3           83434.0300
# 4          149907.3900
# ...                ...
# 25475       77092.5700
# 25476      279174.7900
# 25477      146298.8500
# 25478       86154.7700
# 25479       70876.9100
#
# [25480 rows x 1 columns]

# %% [markdown]
# - len
#
# - min
#
# - max
#
# - average (mean)
#
# - median
#
# - stanrdard deviation std
#
# - 25p
#
# - 50p
#
# - 75p

# %% [markdown]
# **length**

# %%
len(visa_df['prevailing_wage'])
# Out:
# 25480

# %% [markdown]
# **min**

# %%
min(visa_df['prevailing_wage'])
# Out:
# 2.1367

# %% [markdown]
# **max**

# %%
max(visa_df['prevailing_wage'])
# Out:
# 319210.27

# %%
count=len(visa_df['prevailing_wage'])
min_wage=min(visa_df['prevailing_wage'])
max_wage=max(visa_df['prevailing_wage'])
print("The number of wage sample are:",count)
print("The minimum wage is :",min_wage)
print("The maximum wage is :",max_wage)
# Out:
# The number of wage sample are: 25480
# The minimum wage is : 2.1367
# The maximum wage is : 319210.27

# %% [markdown]
# **mean**

# %%
visa_df[['prevailing_wage']].mean()
# Out:
# prevailing_wage    74455.814592
# dtype: float64

# %%
visa_df['prevailing_wage'].mean()
# Out:
# 74455.81459209183

# %% [markdown]
# **median**

# %%
visa_df['prevailing_wage'].median()
# Out:
# 70308.20999999999

# %%
mean_wage=round(visa_df['prevailing_wage'].mean(),2)
median_wage=round(visa_df['prevailing_wage'].median(),2)
print("The average wage is :",mean_wage)
print("The median wage is :",median_wage)
# Out:
# The average wage is : 74455.81
# The median wage is : 70308.21

# %% [markdown]
# - mode is not a suitable metric for numerical analysis
#
# - Different observation can have same valuesm

# %% [markdown]
# **Using numpy**

# %%
np.mean(visa_df['prevailing_wage'])
# Out:
# 74455.81459209183

# %%
np.median(visa_df['prevailing_wage'])
# Out:
# 70308.20999999999

# %% [markdown]
# # standard deviation STD

# %%
std_wage=round(visa_df['prevailing_wage'].std(),2)
std_wage
# Out:
# 52815.94

# %%
# no wrong
list1=[]
list2=[]
for i,j in dict(visa_df.dtypes).items():
    if j=='object':
        list1.append(i)
    else:
        list2.append(i)

# %%
list1,list2
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees', 'yr_of_estab', 'prevailing_wage'])

# %%
count_wage=len(visa_df['prevailing_wage'])
min_wage=min(visa_df['prevailing_wage'])
max_wage=max(visa_df['prevailing_wage'])
mean_wage=round(visa_df['prevailing_wage'].mean(),2)
median_wage=round(visa_df['prevailing_wage'].median(),2)
std_wage=round(visa_df['prevailing_wage'].std(),2)
print("The number of wage sample are:",count)
print("The minimum wage is :",min_wage)
print("The maximum wage is :",max_wage)
print("The average wage is :",mean_wage)
print("The median wage is :",median_wage)
print("The std wage is :",std_wage)
# Out:
# The number of wage sample are: 25480
# The minimum wage is : 2.1367
# The maximum wage is : 319210.27
# The average wage is : 74455.81
# The median wage is : 70308.21
# The std wage is : 52815.94

# %%
# step-1 
values=[count_wage,min_wage,max_wage,mean_wage,median_wage,std_wage]
index=['count','min','max','mean','median','std']
df=pd.DataFrame(values,index=index,columns=['prevailing_wage'])
df
# Out:
#         prevailing_wage
# count        25480.0000
# min              2.1367
# max         319210.2700
# mean         74455.8100
# median       70308.2100
# std          52815.9400

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %% [markdown]
# # 25p-50p-75p

# %% [markdown]
# **Percentile**
#
# - In numpy we have percentile
#
# - This method is np.percentile()
#
#      - It takes the two arguments
#
#      - a: array means data
#
#      - q value which percentile data we want , that value we need to provide
#
#      - if we want 25 value than q=25
#
# **Quantile**
#
# - In numpy we have quantile menthod
#
# - The menthod is np.quantile()
#
# - It takes the two arguments
#
#          - a: array means data
#
#          - q value which percentile data we want , that value we need to provide
#
#          - if we want 25 value than q=0.25

# %%
np.percentile(visa_df['prevailing_wage'],25)   # 0 to 100
# Out:
# 34015.479999999996

# %%
np.quantile(visa_df['prevailing_wage'],0.25)   # 0 to 1
# Out:
# 34015.479999999996

# %%
wage_25=round(np.percentile(visa_df['prevailing_wage'],25),2)
wage_50=round(np.percentile(visa_df['prevailing_wage'],50),2)  
wage_75=round(np.percentile(visa_df['prevailing_wage'],75),2)  
print("25p value is :",wage_25)
print("50p value is :",wage_50)
print("75p value is :",wage_75)
# Out:
# 25p value is : 34015.48
# 50p value is : 70308.21
# 75p value is : 107735.51

# %%
wage_25=round(np.quantile(visa_df['prevailing_wage'],0.25) ,2)
wage_50=round(np.quantile(visa_df['prevailing_wage'],0.50) ,2)  
wage_75=round(np.quantile(visa_df['prevailing_wage'],0.75) ,2)  
print("0.25p value is :",wage_25)
print("0.50p value is :",wage_50)
print("0.75p value is :",wage_75)
# Out:
# 0.25p value is : 34015.48
# 0.50p value is : 70308.21
# 0.75p value is : 107735.51

# %%
values=[count_wage,min_wage,max_wage,mean_wage,median_wage,std_wage,wage_25,wage_50,wage_75]
index=['count','min','max','mean','median','std','25p','50p','75p']
df1=pd.DataFrame(values,index=index,columns=['prevailing_wage'])
df1
# Out:
#         prevailing_wage
# count        25480.0000
# min              2.1367
# max         319210.2700
# mean         74455.8100
# median       70308.2100
# std          52815.9400
# 25p          34015.4800
# 50p          70308.2100
# 75p         107735.5100

# %%
count_wage=len(visa_df['prevailing_wage'])
min_wage=min(visa_df['prevailing_wage'])
max_wage=max(visa_df['prevailing_wage'])
mean_wage=round(visa_df['prevailing_wage'].mean(),2)
median_wage=round(visa_df['prevailing_wage'].median(),2)
std_wage=round(visa_df['prevailing_wage'].std(),2)
wage_25=round(np.percentile(visa_df['prevailing_wage'],25),2)
wage_50=round(np.percentile(visa_df['prevailing_wage'],50),2)  
wage_75=round(np.percentile(visa_df['prevailing_wage'],75),2)

# %%
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
final_df=pd.DataFrame()
for i in num_columns:
    count_wage=len(visa_df[i])
    min_wage=min(visa_df[i])
    max_wage=max(visa_df[i])
    mean_wage=round(visa_df[i].mean(),2)
    median_wage=round(visa_df[i].median(),2)
    std_wage=round(visa_df[i].std(),2)
    wage_25=round(np.percentile(visa_df[i],25),2)
    wage_50=round(np.percentile(visa_df[i],50),2)  
    wage_75=round(np.percentile(visa_df[i],75),2) 
    values=[count_wage,min_wage,max_wage,mean_wage,median_wage,std_wage,wage_25,wage_50,wage_75]
    index=['count','min','max','mean','median','std','25%','50%','75%']
    df1=pd.DataFrame(values,index=index,columns= [i])
    final_df=pd.concat([df1,final_df],axis=1)

# %%
final_df
# Out:
#         prevailing_wage  yr_of_estab  no_of_employees
# count        25480.0000     25480.00         25480.00
# min              2.1367      1800.00           -26.00
# max         319210.2700      2016.00        602069.00
# mean         74455.8100      1979.41          5667.04
# median       70308.2100      1997.00          2109.00
# std          52815.9400        42.37         22877.93
# 25%          34015.4800      1976.00          1022.00
# 50%          70308.2100      1997.00          2109.00
# 75%         107735.5100      2005.00          3504.00

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import os

# %%
visa_df=pd.read_csv(r'C:\Users\param\OneDrive\Documents\EDA file\DataFile\Visadataset.csv')
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
25480-34015
# Out:
# -8535

# %%
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
df1=pd.DataFrame()
for i in num_columns:
    Count=len(visa_df[i])
    Min=min(visa_df[i])
    Max=max(visa_df[i])
    Mean=round(visa_df[i].mean(),2)
    Median=round(visa_df[i].median(),2)
    Std=round(visa_df[i].std(),2)
    p_25=round(np.percentile(visa_df[i],25),2)
    p_50=round(np.percentile(visa_df[i],50),2)
    p_75=round(np.percentile(visa_df[i],75),2)
    values=[Count,Min,Max,Mean,Median,Std,p_25,p_50,p_75]
    index=['Count','Min','Max','Mean','Median','Std','p_25','p_50','p_75']
    cols=[i]
    df2=pd.DataFrame(values,index=index,columns=cols)
    df1=pd.concat([df1,df2],axis=1)

# %%
df1
# Out:
#         no_of_employees  yr_of_estab  prevailing_wage
# Count          25480.00     25480.00       25480.0000
# Min              -26.00      1800.00           2.1367
# Max           602069.00      2016.00      319210.2700
# Mean            5667.04      1979.41       74455.8100
# Median          2109.00      1997.00       70308.2100
# Std            22877.93        42.37       52815.9400
# p_25            1022.00      1976.00       34015.4800
# p_50            2109.00      1997.00       70308.2100
# p_75            3504.00      2005.00      107735.5100

# %% [markdown]
# # percentiles
#
# - 25p:
#
#     - Assume that 25p value = x
#
#     - 25 percentage of data less than value : x
#
# - For example prevailing_wage 25p value is : 34015.14
#
# - 25 percentage of people has salary less than 34015.47
#
# - Total members : 25480
#
# - 25 percentage of 25480 = 6370
#
# - which means 6370 people has salary less than 34015.47

# %%
25*25480/100
# Out:
# 6370.0

# %%
# step-1 Read the prevailaing wage
# step-2 provide the condition 
#    prevailing wage < percentile  value

wage_data=visa_df['prevailing_wage']
p_25=np.percentile(visa_df['prevailing_wage'],25)
con=wage_data<p_25
len(visa_df[con])
# Out:
# 6370

# %%
wage_data=visa_df['prevailing_wage']
p_50=np.percentile(wage_data,50)
con=wage_data<p_50
len(visa_df[con])
# Out:
# 12740

# %%
wage_data=visa_df['prevailing_wage']
p_75=np.percentile(wage_data,75)
con=wage_data<p_75
len(visa_df[con])
# Out:
# 19110

# %% [markdown]
# # Empirical rule

# %% [markdown]
# - mean-1*std to mean+1*std : 68%
# - mean-2*std to mean+2*std : 95%
# - mean-3*std to mean+3*std : 99.7%

# %%
# step-1: calculate the meann of prevaialing wage
# step-2: calculate the std of prevailig wage
# step-3: lb=mean-1*std
# step-4: ub=mean+1*std
# step-5: con1= data<ub
# step-6: con2= data>lb
# step-7: con3= con1 and con2
# step-8: data[con3]
# step-9: compare with 68% 25480 count

# %%
mean = visa_df['prevailing_wage'].mean()
std = visa_df['prevailing_wage'].std()
lb = mean-1*std
ub = mean+1*std
con1=visa_df['prevailing_wage'] < ub
con2=visa_df['prevailing_wage'] > lb
con3= con1 & con2
visa_df[con3]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# 6         EZYV07      Asia            Bachelor's                  N
# ...          ...       ...                   ...                ...
# 25473  EZYV25474      Asia            Bachelor's                  Y
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 1                         N             2412         2002
# ...

# %%
data=visa_df['prevailing_wage']
for i in range(1,4):
    mean = visa_df['prevailing_wage'].mean()
    std = visa_df['prevailing_wage'].std()
    lb = mean-i*std
    ub = mean+i*std
    con1=visa_df['prevailing_wage'] < ub
    con2=visa_df['prevailing_wage'] > lb
    con3= con1 & con2
    if i==1:
            print(f'This is 68% of data count : {len(data[con3])}')
    elif i==2:
            print(f'This is 95% of data count : {len(data[con3])}')
    else:
            print(f'This is 99.7% of data count : {len(data[con3])}')
# Out:
# This is 68% of data count : 17171
# This is 95% of data count : 24582
# This is 99.7% of data count : 25186

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
visa_df=pd.read_csv(r'C:\Users\param\OneDrive\Documents\EDA file\DataFile\Visadataset.csv')
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat_columns=visa_df.select_dtypes(include='object').columns
num_columns=visa_df.select_dtypes(exclude='object').columns
cat_columns,num_columns
# Out:
# (Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#         'requires_job_training', 'region_of_employment', 'unit_of_wage',
#         'full_time_position', 'case_status'],
#        dtype='object'),
#  Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object'))

# %%
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# # Describe

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %% [markdown]
# # Histogram
#
# - By applying imperical rule we observed slight deviation in the count of data
#
# - Also mean is slightly deviated from median
#
# - To understand more clearly  will visulaize the data
#
# - Its is numerical data , so the plot name is : **Histogram**
#
# - Histogram is a  graph between class intervals and class intervals frequeny
#
# - The plot is available in **matplotlib**
#
# - The mathod name is **hist**
#
#
#
#
# -  Histogram will  return 3 values
#
#         - Interval count array
#
#         - we have 20 intervals  , so we have 20 interval counts
#
# - Bins
#
#      - bins means number of intervals
#
#      - we have 20 intervals so we need 21 values
#
#
#
# - will display how many intervals are availabels
#
# - For example in the bins array the first two forms one interval
# -
# 2.136 to 15962.543 the count is 386
#
# -
# 3863 observation are available between 2.136 to 15962.54
# - 3
# silmilarly 2175 observations are avialble between (15962.5434, 31922.95)

# %%
#step-1 : Read the

# %%
visa_df['prevailing_wage']
plt.hist(visa_df['prevailing_wage'],bins=20)
# Out:
# (array([3863., 2175., 2676., 2828., 2889., 2792., 2485., 2066., 1452.,
#          882.,  408.,  216.,  206.,  167.,  129.,  111.,   66.,   48.,
#           10.,   11.]),
#  array([2.13670000e+00, 1.59625434e+04, 3.19229500e+04, 4.78833567e+04,
#         6.38437634e+04, 7.98041700e+04, 9.57645767e+04, 1.11724983e+05,
#         1.27685390e+05, 1.43645797e+05, 1.59606203e+05, 1.75566610e+05,
#         1.91527017e+05, 2.07487423e+05, 2.23447830e+05, 2.39408237e+05,
#         2.55368643e+05, 2.71329050e+05, 2.87289457e+05, 3.03249863e+05,
#         3.19210270e+05]),
#  <BarContainer object of 20 artists>)

# %%
1.59625434e+04
# Out:
# 15962.5434

# %%
visa_df['prevailing_wage']
count,bins,x=plt.hist(visa_df['prevailing_wage'],bins=20)
print(len(count))
print(len(bins))
print(x)
# Out:
# 20
# 21
# <BarContainer object of 20 artists>

# %% [markdown]
# **Verify below two statements**
#
# - 3863 observation are availabel between 2.136 to 15962.543
#
# - similarly 2175 observations are availabel between (15962.5434 to

# %%
lb= 2.136 
ub= 15962.543
con1=visa_df['prevailing_wage']<ub
con2=visa_df['prevailing_wage']>lb
con3=con1&con2
(visa_df[con3])
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 16        EZYV17         Europe              Master's                  Y
# 36        EZYV37         Europe           High School                  Y
# 54        EZYV55           Asia              Master's                  Y
# ...          ...            ...                   ...                ...
# 25460  EZYV25461         Europe              Master's                  Y
# 25461  EZYV25462           Asia              Master's                  Y
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
count
# Out:
# array([3863., 2175., 2676., 2828., 2889., 2792., 2485., 2066., 1452.,
#         882.,  408.,  216.,  206.,  167.,  129.,  111.,   66.,   48.,
#          10.,   11.])

# %%
bins
# Out:
# array([2.13670000e+00, 1.59625434e+04, 3.19229500e+04, 4.78833567e+04,
#        6.38437634e+04, 7.98041700e+04, 9.57645767e+04, 1.11724983e+05,
#        1.27685390e+05, 1.43645797e+05, 1.59606203e+05, 1.75566610e+05,
#        1.91527017e+05, 2.07487423e+05, 2.23447830e+05, 2.39408237e+05,
#        2.55368643e+05, 2.71329050e+05, 2.87289457e+05, 3.03249863e+05,
#        3.19210270e+05])

# %%
lb= 1.59625434e+04
ub= 3.19229500e+04
con1=visa_df['prevailing_wage']<ub
con2=visa_df['prevailing_wage']>lb
con3=con1&con2
(visa_df[con3])
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 12        EZYV13      Asia            Bachelor's                  Y
# 17        EZYV18      Asia              Master's                  Y
# 44        EZYV45      Asia           High School                  Y
# 45        EZYV46    Europe            Bachelor's                  N
# 100      EZYV101      Asia              Master's                  Y
# ...          ...       ...                   ...                ...
# 25404  EZYV25405   Oceania             Doctorate                  Y
# 25410  EZYV25411      Asia              Master's                  Y
# 25445  EZYV25446      Asia            Bachelor's                  Y
# 25457  EZYV25458      Asia              Master's                  Y
# 25473  EZYV25474      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 12                        N           123876         1963
# ...

# %%
df=pd.DataFrame(zip(bins,bins,count),columns=['Bins','bins','count'])
df
# Out:
#              Bins           bins   count
# 0        2.136700       2.136700  3863.0
# 1    15962.543365   15962.543365  2175.0
# 2    31922.950030   31922.950030  2676.0
# 3    47883.356695   47883.356695  2828.0
# 4    63843.763360   63843.763360  2889.0
# 5    79804.170025   79804.170025  2792.0
# 6    95764.576690   95764.576690  2485.0
# 7   111724.983355  111724.983355  2066.0
# 8   127685.390020  127685.390020  1452.0
# 9   143645.796685  143645.796685   882.0
# 10  159606.203350  159606.203350   408.0
# 11  175566.610015  175566.610015   216.0
# 12  191527.016680  191527.016680   206.0
# 13  207487.423345  207487.423345   167.0
# 14  223447.830010  223447.830010   129.0
# 15  239408.236675  239408.236675   111.0
# 16  255368.643340  255368.643340    66.0
# 17  271329.050005  271329.050005    48.0
# 18  287289.456670  287289.456670    10.0
# 19  303249.863335  303249.863335    11.0

# %%
list1=[]
for i in range(len(bins)):
    if i==20:
        break
    else:
        a=round(bins[i],2)
        b=round(bins[i+1],2)
        list1.append(f'{a} to {b}')

list1
df=pd.DataFrame(zip(list1,count),columns=['IF','F'])
df
# Out:
#                         IF       F
# 0         2.14 to 15962.54  3863.0
# 1     15962.54 to 31922.95  2175.0
# 2     31922.95 to 47883.36  2676.0
# 3     47883.36 to 63843.76  2828.0
# 4     63843.76 to 79804.17  2889.0
# 5     79804.17 to 95764.58  2792.0
# 6    95764.58 to 111724.98  2485.0
# 7   111724.98 to 127685.39  2066.0
# 8    127685.39 to 143645.8  1452.0
# 9     143645.8 to 159606.2   882.0
# 10   159606.2 to 175566.61   408.0
# 11  175566.61 to 191527.02   216.0
# 12  191527.02 to 207487.42   206.0
# 13  207487.42 to 223447.83   167.0
# 14  223447.83 to 239408.24   129.0
# 15  239408.24 to 255368.64   111.0
# 16  255368.64 to 271329.05    66.0
# 17  271329.05 to 287289.46    48.0
# 18  287289.46 to 303249.86    10.0
# 19  303249.86 to 319210.27    11.0
